# %%
class Stack(object):
    def __init__(self, limit=10):
        self.stk = []
        self.limit = limit

    def is_empty(self):
        return len(self.stk) <= 0

    def push(self, item):
        if len(self.stk) >= self.limit:
            print('Stack Overflow!')
        else:
            self.stk.append(item)
            print('Stack after push:', self.stk)

    def pop(self):
        if len(self.stk) <= 0:
            print('Stack Underflow!')
            return 0
        else:
            return self.stk.pop()

    def peek(self):
        if len(self.stk) <= 0:
            print('Stack Underflow!')
        else:
            return self.stk[-1]

    def size(self):
        return len(self.stk)

    def display(self):
        print("Stack elements:", self.stk)

# %%
our_stack = Stack(5)

our_stack.push('7')
our_stack.push('21')
our_stack.push('16')
our_stack.push('31')
our_stack.push('19')
our_stack.push('3')
our_stack.push('99')
our_stack.push('9')

print(our_stack.peek()) 
our_stack.display() 

print(our_stack.pop()) 
our_stack.display() 

print(our_stack.peek()) 
our_stack.display() 

print(our_stack.pop()) 
our_stack.display()
# Out:
# Stack after push: ['7']
# Stack after push: ['7', '21']
# Stack after push: ['7', '21', '16']
# Stack after push: ['7', '21', '16', '31']
# Stack after push: ['7', '21', '16', '31', '19']
# Stack Overflow!
# Stack Overflow!
# Stack Overflow!
# 19
# Stack elements: ['7', '21', '16', '31', '19']
# 19
# Stack elements: ['7', '21', '16', '31']
# 31
# Stack elements: ['7', '21', '16', '31']
# 31
# Stack elements: ['7', '21', '16']
